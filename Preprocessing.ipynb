# %% [markdown]
# # Text preprocessing for Christian Urmi and Barwar texts

# %% [markdown]
# In order to work with the language data in the NENA corpus, it is important to separate the language text from other data, such as titles, authors/informants, and verse numbers.

# %% [markdown]
# Our version of the text comes in MS-Word document files. That is probably also the version of the text that is the richest in language data. It contains not only the text itself, but also meaningful formatting, e.g. word markers set in superscript, and loan words set in roman type (where the regular text is set in italic type).

# %% [markdown]
# To convert that information from a Word document to something that we can use in Python, we first convert the word documents to HTML, using LibreOffice in headless mode. It is assumed that the Word files are in the subdirectory `texts`, where the converted `.html` files will also be saved.

# %% [markdown]
#     $ soffice --headless --convert-to html texts/*.doc

# %% [markdown]
# This produces HTML 4.0 documents in the same directory. Earlier attempts with XHTML using wvWare/AbiWord, or LibreOffice using the XHTML conversion filter, produced output that was more difficult to parse or lacked certain characters that were lost in conversion. Although the conversion with LibreOffice takes a very long time compared with AbiWord, the resulting text seems more reliable.

# %% [markdown]
# The custom `nena_corpus` package contains the `Text` class, and several functions that assist in the conversion from HTML, of which we only need the function `html_to_text()`.
#
# The function `html_to_text()` is a generator function yielding `Text` objects, each containing one paragraph of text.
#
# The `Text` class contains a string `p_type` describing the type of paragraph (e.g., `'sectionheading'`, `'p'`, or `'footnote'`), and a list of tuples, containing the text and text style. A text like `'Normal, <i>cursive,</i> and normal'` becomes `[('Normal, ', ''), ('cursive,', 'italic'), (' and normal', '')]`. `Text` objects are iterable. New items can be appended with the `append(text, text_style)` method.

# %%
from nena_corpus import Text, html_to_text

# %% [markdown]
# A small demonstration of the `Text` class:

# %%
p = Text(p_type='test', default_style='normal')

p.append('Dit is ')
p.append('een test', 'test')
p.append('.')

# str(p) returns concatenated string
print(p)
# repr(p) returns class name, p_type and str(p)
print(repr(p))
# list(p) returns the list of tuples
print(list(p))
# a list comprehension also works
print([e for e in p])
# Out:
# Dit is een test.
# <Text 'test' 'Dit is een test.'>
# [('Dit is ', 'normal'), ('een test', 'test'), ('.', 'normal')]
# [('Dit is ', 'normal'), ('een test', 'test'), ('.', 'normal')]

# %% [markdown]
# In the NENA text corpus, word markers are used to indicate loan words and other text attributes. These word markers are set in superscript type. The `html_to_text()` function can recognize them, provided that it knows which ones to look for. A list (or other iterable collection) of markers can be provided in the `markers` keyword argument.

# %% [markdown]
# Since in HTML all consecutive whitespace inside a block element is treated like a space character, `html_to_text()` also converts whitespace to spaces. It can also replace other characters or strings, if they are provided as a dictionary in the `replace` keyword argument. Replacing certain characters, such as visually similar but actually different characters (e.g. `U+01DD 'ǝ' LATIN SMALL LETTER TURNED E` and `U+0259 'ə' LATIN SMALL LETTER SCHWA`), is important later for search and comparison.

# %%
# Word markers
markers_around = {
    'Arm': 'Arm(enian?)',
    'Az': 'Az(eri?)',
    'E': 'English',
    'F': 'French',
    'Ge': 'Ge(rman?)',
    'P': 'P(ersian?)',
    'R': 'R(ussian?)',
}

markers_before = {
    '+': 'stress?',
}

markers_after = {
    '|': 'end stress?',
}

markers = dict(markers_around.items() | markers_before.items() | markers_after.items())

# Characters to be replaced
replace = {
    # U+2011 'NON-BREAKING HYPHEN' has same function as normal hyphen.
    # Replaced by regular U+002D 'HYPHEN-MINUS'
    '\u2011': '\u002d',
    # U+01DD 'LATIN SMALL LETTER TURNED E'
    # Replaced by U+0259 'LATIN SMALL LETTER SCHWA' (looks the same).
    '\u01dd': '\u0259',
    # Deprecated SIL character U+F1EA 'MODIFIER LETTER SHORT EQUALS SIGN'
    # (https://scripts.sil.org/cms/scripts/page.php?site_id=nrsi&id=PUA_Deprecated)
    # replaced by U+003D '=' 'EQUALS SIGN'
    '\uf1ea': '\u003d',
    # U+2026 '…' HORIZONTAL ELLIPSIS
    # replaced by three dots
    '\u2026': '...',
        
    # digraph 'J' LATIN CAPITAL LETTER J and 
    # U+0335 '̵' COMBINING SHORT STROKE OVERLAY or
    # U+0336 '̶' COMBINING LONG STROKE OVERLAY:
    # represents U+0248 'Ɉ' LATIN CAPITAL LETTER J WITH STROKE?
    # (capital equivalent of:
    # U+025f 'ɟ' LATIN SMALL LETTER DOTLESS J WITH STROKE?)
    # occurs 3x:
    # Urmi_C B1 The Assyrians of Urmi 20 (p.238): ... J̶avìlan ... # (long stroke overlay)
    # Urmi_C B7 Village Life 15 (p.288): ... mən-J̵avìlan ... # (short stroke overlay)
    # Urmi_C B17 Village Life 40 (p.344): ... ɟu-J̵úrjəs-+tan| ... # (short stroke overlay)
    'J\u0335': '\u0248',
    'J\u0336': '\u0248',
    
    # Hyphen and circumflex accent below must switch positions
    '\u002d\u032d': '\u032d\u002d',
    # also '\u2011', since in an unordered dictionary,
    # it is unknown which substitution will take place first
    '\u2011\u032d': '\u032d\u002d',
}

# %% [markdown]
# ## Importing the texts

# %% [markdown]
# Assuming that the subdirectory `texts` contains the HTML files generated earlier, we can import all files in the pattern `texts/*.html`. At this point we just want to do language statistics and not look at the actual texts, so it is sufficient to import the paragraphs of all texts in no particular order.

# %%
import pathlib

html_files = pathlib.Path.cwd().glob('texts/*.html')

paragraphs = []

for inputfile in html_files:
    print(inputfile.name, end=' ')
    for p in html_to_text(inputfile, markers=markers, replace=replace):
        print('.', end='')
        paragraphs.append(p)
    print(' done.')

len(paragraphs)
# Out:
# bar text A14.html .................. done.
# bar text a29.html ........... done.
# bar text A49.html ......................... done.
# bar text a28.html ...... done.
# bar text a50-A52.html ................................................................................................................... done.
# bar text A45.html .... done.
# bar text a31-A33.html ................ done.
# bar text A42-A44.html ............ done.
# bar text a25.html .................. done.
# bar text a30.html .......... done.
# bar text a34.html .......... done.
# bar text a19-A23.html ............................... done.
# bar text a24.html ........ done.
# bar text a18.html .... done.
# bar text A37-A40.html .................................................................... done.
# bar text a1-A7.html ............................... done.
# bar text a36.html ... done.
# bar text a41.html ... done.
# cu vol 4 texts.html ......................................................................................................................................................................................................................................................................................................................................... done.
# bar text a8.html ........... done.
# bar text a26.html .......... done.
# bar text a48.html ...... done.
# bar text a46-A47.html ....... done.
# bar text a35.html ...... done.
# bar text a27.html ........... done.
# bar text A9-A13.html ........................ done.
# bar text a15-A17.html ............ done.
# 809

# %% [markdown]
# Now we have imported 809 paragraphs of text. We only need the paragraphs containing the actual texts. We can look at the `p_type`s to see what paragraphs we have:

# %%
set(p._p_type for p in paragraphs)
# Out:
# {'footer',
#  'gp-sectionheading-western',
#  'gp-subsectionheading-western',
#  'gp-subsubsectionheading-western',
#  'p',
#  'sdfootnote1',
#  'sdfootnote2'}

# %% [markdown]
# Only the paragraphs with p_type `'p'` contain the actual text, the others are headings or footnotes.

# %% [markdown]
# The `'p'` paragraphs contain differently styled texts. The styles include the markers defined above, `'verse_no'` and `'fn_anchor'`, besides the normal text styles `'italic'` and `''` (unstyled, roman, text):

# %%
set(style for p in paragraphs if p._p_type == 'p' for text, style in p)
# Out:
# {'',
#  '+',
#  'Arm',
#  'Az',
#  'E',
#  'F',
#  'Ge',
#  'P',
#  'R',
#  'fn_anchor',
#  'italic',
#  'verse_no',
#  '|'}

# %% [markdown]
# We are only interested in the normal text styles, so we filter out all others for the statistics. We want to know all the different characters that occur in the texts. Since many characters consist of combinations of a letter with one or more combining diacritics, we combine those first.

# %%
import collections
import unicodedata

import pandas

characters = collections.Counter()

for p in paragraphs:
    if p._p_type != 'p':
        continue
    for text, text_style in p:
        if text_style not in ('verse_no', 'fn_anchor', *markers):
            char = ''
            for c in text:
                if char and unicodedata.category(c) == 'Mn':
                    char += c
                elif char:
                    characters[char] += 1
                    char = c
                else:
                    char = c
            if char:
                characters[char] += 1

# make pandas not truncate the table rows
pandas.set_option('display.max_rows', 300)

data = []
for c in sorted(characters):
    data.append({'character': c,
                 'count': characters[c],
                 'category': unicodedata.category(c[0]),
                 'hex codes': ' + '.join([hex(ord(e)) for e in c]),
                 'name': unicodedata.name(c[0], 'Unknown'),
                })

df = pandas.DataFrame(data)
df.style.set_properties({'text-align': 'left'})
df.sort_values(['category', 'character'])
# Out:
#     category character  count              hex codes  \
# 57        Ll         a  63409                   0x61
# 58        Ll        à  16165           0x61 + 0x300
# 59        Ll        á  26877           0x61 + 0x301
# 60        Ll       ã̀      1   0x61 + 0x303 + 0x300
# 61        Ll        ā    270           0x61 + 0x304
# 62        Ll       ā̀    206   0x61 + 0x304 + 0x300
# 63        Ll       ā́    183   0x61 + 0x304 + 0x301
# 64        Ll        ă    646           0x61 + 0x306
# 65        Ll       ằ    299   0x61 + 0x306 + 0x300
# 66        Ll       ắ    600   0x61 + 0x306 + 0x301
# 67        Ll        ä      2           0x61 + 0x308
# 68        Ll       ä̀      2   0x61 + 0x308 + 0x300
# 69        Ll         b  14437                   0x62
# 70        Ll         c   4046                   0x63
# 71        Ll        ĉ      1           0x63 + 0x302
# 72        Ll        č   1276           0x63 + 0x30c
# 73        Ll       č̣     84   0x63 + 0x323 + 0x30c
# 74        Ll        c̭     40           0x63 + 0x32d
# 75        Ll       č̭    539   0x63 + 0x32d + 0x30c
# 76        Ll         d  13204                   0x64
# 77        Ll        ḍ      4           0x64 + 0x323
# 78        Ll         e  13040                   0x65
# 79        Ll        è   2323           0x65 + 0x300
# 80        Ll        é   2988           0x65 + 0x301
# 81        Ll        ē     84           0x65 + 0x304
# 82        Ll       ḕ    174   0x65 + 0x304 + 0x300
# 83        Ll       ḗ    186   0x65 + 0x304 + 0x301
# 84        Ll         f    326                   0x66
# 85        Ll         g   2303                   0x67
# 86        Ll        ġ    270           0x67 + 0x307
# 87        Ll         h   4341                   0x68
# 88        Ll        ḥ    169           0x68 + 0x323
# 89        Ll         i   9748                   0x69
# 90        Ll        ì   6061           0x69 + 0x300
# 91        Ll        í   9223           0x69 + 0x301
# 92        Ll        ī     75           0x69 + 0x304
# 93        Ll       ī̀     64   0x69 + 0x304 + 0x300
# 94        Ll       ī́     66   0x69 + 0x304 + 0x301
# 95        Ll         j   1409                   0x6a
# 96        Ll         k   2652                   0x6b
# 97        Ll        k̭   6107           0x6b + 0x32d
# 98        Ll         l  39003                   0x6c
# 99        Ll        ḷ    208           0x6c + 0x323
# 100       Ll         m  25693                   0x6d
# 101       Ll        ṃ     24           0x6d + 0x323
# 102       Ll         n  26517                   0x6e
# 103       Ll         o   3698                   0x6f
# 104       Ll        ò   1543           0x6f + 0x300
# 105       Ll        ó   2256           0x6f + 0x301
# 106       Ll        ō     81           0x6f + 0x304
# 107       Ll       ṑ      9   0x6f + 0x304 + 0x300
# 108       Ll       ṓ     28   0x6f + 0x304 + 0x301
# 109       Ll       ŏ̀      1   0x6f + 0x306 + 0x300
# 110       Ll       ŏ́      1   0x6f + 0x306 + 0x301
# 111       Ll         p   5274                   0x70
# 112       Ll        p̂    561           0x70 + 0x302
# 113       Ll        p̣      5           0x70 + 0x323
# 114       Ll        p̭      1           0x70 + 0x32d
# 115       Ll         q   4102                   0x71
# 116       Ll         r  23465                   0x72
# 117       Ll        ŕ      1           0x72 + 0x301
# 118       Ll        ṛ    474           0x72 + 0x323
# 119       Ll         s   5744                   0x73
# 120       Ll        š   8914           0x73 + 0x30c
# 121       Ll        ṣ   1397           0x73 + 0x323
# 122       Ll         t  23867                   0x74
# 123       Ll        ṭ   2072           0x74 + 0x323
# 124       Ll        ṱ   3406           0x74 + 0x32d
# 125       Ll         u  12132                   0x75
# 126       Ll        ù   3866           0x75 + 0x300
# 127       Ll        ú   5030           0x75 + 0x301
# 128       Ll        ū     56           0x75 + 0x304
# 129       Ll       ū̀     78   0x75 + 0x304 + 0x300
# 130       Ll       ū́     38   0x75 + 0x304 + 0x301
# 131       Ll        ŭ     46           0x75 + 0x306
# 132       Ll       ŭ̀      9   0x75 + 0x306 + 0x300
# 133       Ll       ŭ́      3   0x75 + 0x306 + 0x301
# 134       Ll        ü      5           0x75 + 0x308
# 135       Ll       ǜ      1   0x75 + 0x308 + 0x300
# 136       Ll       ǘ      4   0x75 + 0x308 + 0x301
# 137       Ll         v   9058                   0x76
# 138       Ll         w   6186                   0x77
# 139       Ll         x  20574                   0x78
# 140       Ll         y  18676                   0x79
# 141       Ll        ý      1           0x79 + 0x301
# 142       Ll         z   5139                   0x7a
# 143       Ll        ž    212           0x7a + 0x30c
# 144       Ll        ẓ      6           0x7a + 0x323
# 145       Ll         ð   1375                   0xf0
# 146       Ll        ð̣      6           0xf0 + 0x323
# 147       Ll         ı      6                  0x131
# 148       Ll        ı́      3          0x131 + 0x301
# 150       Ll         ɑ      9                  0x251
# 151       Ll        ɑ̀      4          0x251 + 0x300
# 152       Ll        ɑ̄     42          0x251 + 0x304
# 153       Ll       ɑ̄̀     28  0x251 + 0x304 + 0x300
# 154       Ll       ɑ̄́     13  0x251 + 0x304 + 0x301
# 155       Ll         ə  29329                  0x259
# 156       Ll        ə̀   4418          0x259 + 0x300
# 157       Ll        ə́   8180          0x259 + 0x301
# 158       Ll         ɛ   2431                  0x25b
# 159       Ll        ɛ̀    961          0x25b + 0x300
# 160       Ll        ɛ́   1041          0x25b + 0x301
# 161       Ll        ɛ̄      1          0x25b + 0x304
# 162       Ll         ɟ   3028                  0x25f
# 166       Ll         θ   3615                  0x3b8
# 163       Lm         ʾ  19345                  0x2be
# 164       Lm         ʿ    192                  0x2bf
# 13        Lu         A    143                   0x41
# 14        Lu        À     38           0x41 + 0x300
# 15        Lu        Á     20           0x41 + 0x301
# 16        Lu         B    196                   0x42
# 17        Lu         C     10                   0x43
# 18        Lu        Č     64           0x43 + 0x30c
# 19        Lu       Č̭      4   0x43 + 0x32d + 0x30c
# 20        Lu         D     45                   0x44
# 21        Lu         E      1                   0x45
# 22        Lu        È      4           0x45 + 0x300
# 23        Lu        É      1           0x45 + 0x301
# 24        Lu         F     37                   0x46
# 25        Lu         G     75                   0x47
# 26        Lu         H    106                   0x48
# 27        Lu        Ḥ     12           0x48 + 0x323
# 28        Lu         I     16                   0x49
# 29        Lu        Ì     27           0x49 + 0x300
# 30        Lu        Í     17           0x49 + 0x301
# 31        Lu         J     20                   0x4a
# 32        Lu         K     58                   0x4b
# 33        Lu        K̭     12           0x4b + 0x32d
# 34        Lu         L     37                   0x4c
# 35        Lu         M    173                   0x4d
# 36        Lu         N    154                   0x4e
# 37        Lu         O      7                   0x4f
# 38        Lu        Ò      3           0x4f + 0x300
# 39        Lu        Ó      2           0x4f + 0x301
# 40        Lu         P     18                   0x50
# 41        Lu         Q     79                   0x51
# 42        Lu         R     99                   0x52
# 43        Lu         S    124                   0x53
# 44        Lu        Š     34           0x53 + 0x30c
# 45        Lu         T     85                   0x54
# 46        Lu        Ṱ      1           0x54 + 0x32d
# 47        Lu         U      3                   0x55
# 48        Lu        Ù     61           0x55 + 0x300
# 49        Lu        Ú     34           0x55 + 0x301
# 50        Lu         V     10                   0x56
# 51        Lu         W     15                   0x57
# 52        Lu         X     48                   0x58
# 53        Lu         Y     34                   0x59
# 54        Lu         Z    135                   0x5a
# 149       Lu         Ɉ      3                  0x248
# 165       Mn         ́      1                  0x301
# 7         Nd         0      1                   0x30
# 8         Nd         1      1                   0x31
# 5         Pd         -  25281                   0x2d
# 167       Pd         —     27                 0x2014
# 3         Pe         )      6                   0x29
# 56        Pe         ]     28                   0x5d
# 1         Po         !    560                   0x21
# 4         Po         ,   7761                   0x2c
# 6         Po         .  15191                   0x2e
# 9         Po         :     73                   0x3a
# 10        Po         ;      1                   0x3b
# 12        Po         ?   1686                   0x3f
# 2         Ps         (      6                   0x28
# 55        Ps         [     28                   0x5b
# 11        Sm         =   1100                   0x3d
# 0         Zs            92673                   0x20
#
#                                          name
# 57                       LATIN SMALL LETTER A
# 58                       LATIN SMALL LETTER A
# 59                       LATIN SMALL LETTER A
# 60                       LATIN SMALL LETTER A
# 61                       LATIN SMALL LETTER A
# 62                       LATIN SMALL LETTER A
# 63                       LATIN SMALL LETTER A
# 64                       LATIN SMALL LETTER A
# 65                       LATIN SMALL LETTER A
# 66                       LATIN SMALL LETTER A
# 67                       LATIN SMALL LETTER A
# 68                       LATIN SMALL LETTER A
# 69                       LATIN SMALL LETTER B
# 70                       LATIN SMALL LETTER C
# 71                       LATIN SMALL LETTER C
# 72                       LATIN SMALL LETTER C
# 73                       LATIN SMALL LETTER C
# 74                       LATIN SMALL LETTER C
# 75                       LATIN SMALL LETTER C
# 76                       LATIN SMALL LETTER D
# 77                       LATIN SMALL LETTER D
# 78                       LATIN SMALL LETTER E
# 79                       LATIN SMALL LETTER E
# 80                       LATIN SMALL LETTER E
# 81                       LATIN SMALL LETTER E
# 82                       LATIN SMALL LETTER E
# 83                       LATIN SMALL LETTER E
# 84                       LATIN SMALL LETTER F
# 85                       LATIN SMALL LETTER G
# 86                       LATIN SMALL LETTER G
# 87                       LATIN SMALL LETTER H
# 88                       LATIN SMALL LETTER H
# 89                       LATIN SMALL LETTER I
# 90                       LATIN SMALL LETTER I
# 91                       LATIN SMALL LETTER I
# 92                       LATIN SMALL LETTER I
# 93                       LATIN SMALL LETTER I
# 94                       LATIN SMALL LETTER I
# 95                       LATIN SMALL LETTER J
# 96                       LATIN SMALL LETTER K
# 97                       LATIN SMALL LETTER K
# 98                       LATIN SMALL LETTER L
# 99                       LATIN SMALL LETTER L
# 100                      LATIN SMALL LETTER M
# 101                      LATIN SMALL LETTER M
# 102                      LATIN SMALL LETTER N
# 103                      LATIN SMALL LETTER O
# 104                      LATIN SMALL LETTER O
# 105                      LATIN SMALL LETTER O
# 106                      LATIN SMALL LETTER O
# 107                      LATIN SMALL LETTER O
# 108                      LATIN SMALL LETTER O
# 109                      LATIN SMALL LETTER O
# 110                      LATIN SMALL LETTER O
# 111                      LATIN SMALL LETTER P
# 112                      LATIN SMALL LETTER P
# 113                      LATIN SMALL LETTER P
# 114                      LATIN SMALL LETTER P
# 115                      LATIN SMALL LETTER Q
# 116                      LATIN SMALL LETTER R
# 117                      LATIN SMALL LETTER R
# 118                      LATIN SMALL LETTER R
# 119                      LATIN SMALL LETTER S
# 120                      LATIN SMALL LETTER S
# 121                      LATIN SMALL LETTER S
# 122                      LATIN SMALL LETTER T
# 123                      LATIN SMALL LETTER T
# 124                      LATIN SMALL LETTER T
# 125                      LATIN SMALL LETTER U
# 126                      LATIN SMALL LETTER U
# 127                      LATIN SMALL LETTER U
# 128                      LATIN SMALL LETTER U
# 129                      LATIN SMALL LETTER U
# 130                      LATIN SMALL LETTER U
# 131                      LATIN SMALL LETTER U
# 132                      LATIN SMALL LETTER U
# 133                      LATIN SMALL LETTER U
# 134                      LATIN SMALL LETTER U
# 135                      LATIN SMALL LETTER U
# 136                      LATIN SMALL LETTER U
# 137                      LATIN SMALL LETTER V
# 138                      LATIN SMALL LETTER W
# 139                      LATIN SMALL LETTER X
# 140                      LATIN SMALL LETTER Y
# 141                      LATIN SMALL LETTER Y
# 142                      LATIN SMALL LETTER Z
# 143                      LATIN SMALL LETTER Z
# 144                      LATIN SMALL LETTER Z
# 145                    LATIN SMALL LETTER ETH
# 146                    LATIN SMALL LETTER ETH
# 147              LATIN SMALL LETTER DOTLESS I
# 148              LATIN SMALL LETTER DOTLESS I
# 150                  LATIN SMALL LETTER ALPHA
# 151                  LATIN SMALL LETTER ALPHA
# 152                  LATIN SMALL LETTER ALPHA
# 153                  LATIN SMALL LETTER ALPHA
# 154                  LATIN SMALL LETTER ALPHA
# 155                  LATIN SMALL LETTER SCHWA
# 156                  LATIN SMALL LETTER SCHWA
# 157                  LATIN SMALL LETTER SCHWA
# 158                 LATIN SMALL LETTER OPEN E
# 159                 LATIN SMALL LETTER OPEN E
# 160                 LATIN SMALL LETTER OPEN E
# 161                 LATIN SMALL LETTER OPEN E
# 162  LATIN SMALL LETTER DOTLESS J WITH STROKE
# 166                  GREEK SMALL LETTER THETA
# 163           MODIFIER LETTER RIGHT HALF RING
# 164            MODIFIER LETTER LEFT HALF RING
# 13                     LATIN CAPITAL LETTER A
# 14                     LATIN CAPITAL LETTER A
# 15                     LATIN CAPITAL LETTER A
# 16                     LATIN CAPITAL LETTER B
# 17                     LATIN CAPITAL LETTER C
# 18                     LATIN CAPITAL LETTER C
# 19                     LATIN CAPITAL LETTER C
# 20                     LATIN CAPITAL LETTER D
# 21                     LATIN CAPITAL LETTER E
# 22                     LATIN CAPITAL LETTER E
# 23                     LATIN CAPITAL LETTER E
# 24                     LATIN CAPITAL LETTER F
# 25                     LATIN CAPITAL LETTER G
# 26                     LATIN CAPITAL LETTER H
# 27                     LATIN CAPITAL LETTER H
# 28                     LATIN CAPITAL LETTER I
# 29                     LATIN CAPITAL LETTER I
# 30                     LATIN CAPITAL LETTER I
# 31                     LATIN CAPITAL LETTER J
# 32                     LATIN CAPITAL LETTER K
# 33                     LATIN CAPITAL LETTER K
# 34                     LATIN CAPITAL LETTER L
# 35                     LATIN CAPITAL LETTER M
# 36                     LATIN CAPITAL LETTER N
# 37                     LATIN CAPITAL LETTER O
# 38                     LATIN CAPITAL LETTER O
# 39                     LATIN CAPITAL LETTER O
# 40                     LATIN CAPITAL LETTER P
# 41                     LATIN CAPITAL LETTER Q
# 42                     LATIN CAPITAL LETTER R
# 43                     LATIN CAPITAL LETTER S
# 44                     LATIN CAPITAL LETTER S
# 45                     LATIN CAPITAL LETTER T
# 46                     LATIN CAPITAL LETTER T
# 47                     LATIN CAPITAL LETTER U
# 48                     LATIN CAPITAL LETTER U
# 49                     LATIN CAPITAL LETTER U
# 50                     LATIN CAPITAL LETTER V
# 51                     LATIN CAPITAL LETTER W
# 52                     LATIN CAPITAL LETTER X
# 53                     LATIN CAPITAL LETTER Y
# 54                     LATIN CAPITAL LETTER Z
# 149        LATIN CAPITAL LETTER J WITH STROKE
# 165                    COMBINING ACUTE ACCENT
# 7                                  DIGIT ZERO
# 8                                   DIGIT ONE
# 5                                HYPHEN-MINUS
# 167                                   EM DASH
# 3                           RIGHT PARENTHESIS
# 56                       RIGHT SQUARE BRACKET
# 1                            EXCLAMATION MARK
# 4                                       COMMA
# 6                                   FULL STOP
# 9                                       COLON
# 10                                  SEMICOLON
# 12                              QUESTION MARK
# 2                            LEFT PARENTHESIS
# 55                        LEFT SQUARE BRACKET
# 11                                EQUALS SIGN
# 0                                       SPACE

# %%
for diacritics in sorted(set(c[1:] for c in characters if len(c) > 1)):
    print(unicodedata.name(diacritics[0]), '\t', ' + '.join([hex(ord(e)) for e in diacritics]))
# Out:
# COMBINING GRAVE ACCENT 	 0x300
# COMBINING ACUTE ACCENT 	 0x301
# COMBINING CIRCUMFLEX ACCENT 	 0x302
# COMBINING TILDE 	 0x303 + 0x300
# COMBINING MACRON 	 0x304
# COMBINING MACRON 	 0x304 + 0x300
# COMBINING MACRON 	 0x304 + 0x301
# COMBINING BREVE 	 0x306
# COMBINING BREVE 	 0x306 + 0x300
# COMBINING BREVE 	 0x306 + 0x301
# COMBINING DOT ABOVE 	 0x307
# COMBINING DIAERESIS 	 0x308
# COMBINING DIAERESIS 	 0x308 + 0x300
# COMBINING DIAERESIS 	 0x308 + 0x301
# COMBINING CARON 	 0x30c
# COMBINING DOT BELOW 	 0x323
# COMBINING DOT BELOW 	 0x323 + 0x30c
# COMBINING CIRCUMFLEX ACCENT BELOW 	 0x32d
# COMBINING CIRCUMFLEX ACCENT BELOW 	 0x32d + 0x30c

# %% [markdown]
# TODO: make a two-dimensional character table
#
# TODO: isolate words
